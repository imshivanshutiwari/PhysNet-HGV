# %% [markdown]
# # 01 - HGV Trajectory Simulation
# This notebook demonstrates the 6-DOF trajectory simulation and plasma modeling.

# %%
from physnet_hgv.simulation.trajectory_gen import TrajectoryGenerator
from physnet_hgv.utils.config_loader import load_config
import yaml

config = load_config('physnet-hgv/configs/hgv_config.yaml')
generator = TrajectoryGenerator(config)
generator.run_batch(5)
