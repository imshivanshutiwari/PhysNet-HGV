# %% [markdown]
# # 03 - Tracking Results
# Comparative analysis of UKF and PhysNet tracking performance.

# %%
from physnet_hgv.evaluation.evaluate import HGVEvaluator
evaluator = HGVEvaluator('physnet-hgv/configs/hgv_config.yaml')
results = evaluator.run_eval(n_steps=100)
print(results)
